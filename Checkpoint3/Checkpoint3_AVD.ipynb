# %% [markdown]
# # **HOSPITAL BEDS MANAGEMENT**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# **Business Objective**
#
#   Rumah Sakit ini ingin tahu bagaimana cara mengatur staf, tempat tidur dan lyanannya agar sesuai dengan jumlah pasien.
#
#   Tujuannya supaya pelayanan lebih lancar, tidak ada kekurangan satf atau tempat tidur, pasien bisa ditanganin secara baik dan membantu rumah sakit mengelola sumber daya dengan lebih baik.
#
#   Dengan tercapainya tujuan tersebut, rumah sakit diharapkan dapat memberikan pelayanan yang lebih efisien, cepat, dan berkualitas kepada pasien.

# %% [markdown]
# **Assess Situation**

# %% [markdown]
# Rumah sakit sebagai instuasi pelayanan kesehatan menghadapi tantangan dalam mengelola sumber daya secara optimal, terutama tenaga medis dan fasilitas tempat tidur. permintaan pasien yang tidak stabil dapat menyebabkan ketidak seimbangan antara kapasitas layanan dan kebutuhan pasien, sehingga berdampak pada kualitas pelayanan dan efisiensi oprasional.
#
#
# Dataset rumah sakit sintetis ini disediakan untuk mensimulasikan kondisi operasional sumah sakit berukuran sedang, sehingga dapat digunaan sebagai bahan anlisis tanpa menggunakan data pasien nyata(untuk menjaga privasi).
#
# adapun masalah yang dihadapi:
# *   tenaga kerja yang tidak merata antar unit layanan.
# *   kelebihan atau kekurangan kapasitas tempat tidur pada unit tertentu.
# *   lonjakan penerimaan pasien yang tidak diantisipasi dengan baik

# %% [markdown]
# **Analytic Goals**

# %% [markdown]
# Jadi tujuan yang ingin dicapai dari sisi analisis data(bukan tujuan bisnis, tapi tujuan teknis datanya)
#
# *  Menghitung rasio
#   pasien dibandikan staf dan Tempat tidur
#
# *  Menganalisis Pola pasien
#   mengetahui  jumlah pasien,karakteristik pasien, dan pola kunjungan
#
# *  Menganalisis penggunaan tempat tidur
#   mengetahui unit mana yang sering penuh dan mana yang jarang digunkan
#
# *  Menganalisis distribusi tenaga kerja
#   melihat apakah jumlah staf sudah seimbang dengan jumlah pasien, Membuat Perkiraan staf jika jumlah pasien meningkat
#
# *   Mencari pola dan insight penting
#   misalnya waktu ramai pasien, unit dengan beban tinggi, dan potensi masalah layanan.

# %% [markdown]
# **Project Plan**

# %% [markdown]
# Project plan menjelaskan tahapan yang akan dilakukan dalam analisis data.
#
# *   Langkah 1: Pahami Data
#
#     Melihatihat isi dataset, jumlah baris/kolom, dan tipe data.
# *   Langkah 2: Siapkan Data
#
#     Bersihkan data dari nilai kosong/duplikat, ubah data kategorialkan jadi angka jika perlu
#
# *   Langkah 3: Analisis dan Modeling
#
#     Hitung rasio pasien/staf, Pasien/Tempat Tidur, buat grafik, dan coba model prediksi sederhana.
#
# *   Langkah 4: Evaluasi
#
#     Melihat hasil analisis, tentukan dapartemen yang paling sibuk, dan buat rekomendasi

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Memuat Dataset**

# %%
path = "/content/drive/MyDrive/AVD/patients.csv"
df = pd.read_csv(path)
df
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# 2    general_medicine            83
# 3           emergency            81
# 4                 ICU            76
# ..                ...           ...
# 995         emergency            91
# 996         emergency            99
# 997               ICU            69
# 998               ICU            61
# 999  general_medicine            83
#
# [1000 rows x 7 columns]

# %% [markdown]
# #**Deskripsi Data**

# %% [markdown]
# ##**Informasi Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   object
#  1   name            1000 non-null   object
#  2   age             1000 non-null   int64
#  3   arrival_date    1000 non-null   object
#  4   departure_date  1000 non-null   object
#  5   service         1000 non-null   object
#  6   satisfaction    1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %% [markdown]
# Berdasarkan data diatas dataset ini memiliki 1000 baris dan 7 kolom

# %% [markdown]
# ##**Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   object
#  1   name            1000 non-null   object
#  2   age             1000 non-null   int64
#  3   arrival_date    1000 non-null   object
#  4   departure_date  1000 non-null   object
#  5   service         1000 non-null   object
#  6   satisfaction    1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %% [markdown]
# 1. Patient_id: Jumlah baris: 1000 Tipe data: Object
# 2. Name: Jumlah baris: 1000 Tipe data: Object
# 3. age: Jumlah baris: 1000 Tipe data: Intj64
# 4. Arrival_date: Jumlah baris: 1000 Tipe data: Object
# 5. Daparture_date: Jumlah baris: 1000 Tipe data: Object
# 6. Service: Jumlah baris: 1000 Tipe data: Object
# 7. Statisfaction: Jumlah baris: 1000 Tipe data: Int64

# %% [markdown]
# ##**Informasi Statistik Deskriftif**

# %%
df.describe(include="all")
# Out:
#           patient_id            name          age arrival_date departure_date  \
# count           1000            1000  1000.000000         1000           1000
# unique          1000             993          NaN          344            337
# top     PAT-e2ef9c5f  Michael Miller          NaN   2025-01-19     2025-10-16
# freq               1               2          NaN            9              8
# mean             NaN             NaN    45.337000          NaN            NaN
# std              NaN             NaN    25.999912          NaN            NaN
# min              NaN             NaN     0.000000          NaN            NaN
# 25%              NaN             NaN    23.000000          NaN            NaN
# 50%              NaN             NaN    46.000000          NaN            NaN
# 75%              NaN             NaN    68.000000          NaN            NaN
# max              NaN             NaN    89.000000          NaN            NaN
#
#           service  satisfaction
# count        1000   1000.000000
# unique          4           NaN
# top     emergency           NaN
# freq          263           NaN
# mean          NaN     79.597000
# std           NaN     11.550325
# min           NaN     60.000000
# 25%           NaN     70.000000
# 50%           NaN     80.000000
# 75%           NaN     89.250000
# max           NaN     99.000000

# %% [markdown]
# 1. Count berdasarkan data, total baris ada 1000.
# *   Profit Lengkap Tidak ada data yang hilang
# *   Tidak Terdapat MIssing Velues terhadap kolom, Patient_id, Name, Age, Arrival_date, Departure_date, Service, Satisfaction.
#
#
#
# ---
#
# 2. Mean vs Median
#
# *   Kolom age
#     Mean = 45.337
#     Median =46.000
#   Nilai median hampir sama dengan mean menunjukan distribusi umur relatif seimbang.
#
# *   Kolom satisfaction
#     Mean = 79.597
#     Median =80.000
#   Rata rata tingkat kepuasan pasien menunjukan tergolong tinggi. hal ini mengindikasikan kualitascpelayanan rumah sakit dalam dataset tergolong baik.
#
# Kesimpulannya: Dataset ini menunjukan bahwa pasien berasal dari berbagai usia, dengan dominan usia dewasa, tingkat kepuasan pasien relatif tinggi dan stabil, rumah sakit secara umum memiliki performa pelayanan yang baik menurut sintetis ini.
#
#
#
#
# ---
#
#
# 3. min dan max
#
# *   Age
#     min = 0
#     max = 89.000
# *   Satisfaction
#     min = 60.000
#     max = 99.000
#
# Kesimpulannya:
#
#
# *   Rentang usia pasien sangat luas (0–89 tahun), menunjukkan rumah sakit melayani semua kelompok usia.
#
# *   Tingkat kepuasan pasien berada pada rentang yang baik (60–99), yang menandakan kualitas layanan rumah sakit tergolong baik.
#
#
#
#
# 4. Standar Deviasi(std)
#
#
# *   Age
#     Mean = 45.337
#     Std = 25.999
#
#
# *   Statisfasion
#     Mean = 79.597
#     Std = 11.550
#
# Kesimpulan:
# *   Variasi usia Pasien tinggi, Rumah sakit melayani banyak kelompok usia.
# *   Variasi kepuasan pasien rendah, Pelayanan rumah sakit dinilai cukup
# konsisten oleh pasien.

# %% [markdown]
# ## **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Pemeriksaan tipe data dilakukan untuk memastikan setiap kolom memiliki tipe data yang sesuai dengan maknanya, sehingga data dapat dianalisis dengan benar.

# %%
df.dtypes
# Out:
# patient_id        object
# name              object
# age                int64
# arrival_date      object
# departure_date    object
# service           object
# satisfaction       int64
# dtype: object

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Inconsistent values adalah perbedaan penulisan data kategori yang seharusnya sama.

# %% [markdown]
# 1. **Name**

# %% [markdown]
# pada kolom ini terdapat potensi nilai tidak konsisten karena perbedaan format penulisan nama (huruf kapital dan spasi). Namun, perbedaan ini tidak mempengaruhi analisis numerik, tetapi dapat mempengaruhi analisis berbasis identitas individu.

# %%
print(df['name'].unique())
# Out:
# ['Richard Rodriguez' 'Shannon Walker' 'Julia Torres' 'Crystal Johnson'
#  'Garrett Lin' 'Diana May' 'William Herrera' 'Ashley Waller'
#  'Victor Baker' 'Jeffrey Chandler' 'Larry Dixon' 'Kenneth Scott'
#  'April Frost' 'Michelle Harmon' 'Helen Jones' 'Erin Edwards'
#  'Michelle Evans' 'Jason Powell' 'Cameron Fisher' 'Megan Orr'
#  'Elizabeth Kelley' 'Dustin Jordan' 'Mary Marshall' 'Daniel Kennedy'
#  'Rebecca Jackson' 'Jose Schultz' 'Robert Potter' 'Courtney Gonzalez'
#  'David Alvarez' 'Angel Perry' 'Cheyenne Horton' 'David Douglas Jr.'
#  'Patricia Rodriguez' 'Christopher Rubio' 'Amber Wright' 'Joyce Solis'
#  'Victoria Larson' 'Stephanie Salazar' 'Kathy Rivas' 'Stephanie Manning'
#  'David Wright' 'Pamela Boyd' 'Denise Jones' 'Devon Flores' 'Brenda Hall'
#  'Michelle Brown' 'Joshua Perry' 'Jason Stein' 'Melissa Gates'
#  'Jamie Smith' 'Paul Castaneda' 'Jennifer Adkins' 'Lindsey Walker'
#  'Jeffrey Johnson' 'Michael Powell' 'John Anderson' 'Alyssa Long'
#  'Alyssa Day' 'Joel Williams' 'Daniel Murphy' 'Jamie Walton'
#  'Darlene Miller' 'Joshua Cooke' 'Matthew Harrington' 'Nicole Herring'
#  'Alex Hernandez' 'Michael Elliott' 'Michael Wang' 'Lawrence Adkins'
#  'Robert Oconnell' 'Alexander Collins' 'Tina Sanders' 'Angela Vaughn'
#  'Ashley Barton' 'Lindsay Martinez' 'Dr. Hannah Patterson'
#  'Jonathan Peterson' 'Samantha Garcia' 'Madison Poole' 'Jessica Gross'
#  'Debra Morton' 'Karen Graham' 'Debra Christian' 'Angelica Keith'
#  'John Bishop' 'Allen Rosales' 'Daniel Salinas' 'Spencer Haynes'
#  'Adam Vaughan' 'Nathan Freeman' 'Melissa Brewer' 'Ricky Davis II'
#  'Elizabeth Perkins' 'Joseph Coleman' 'Erin Warner' 'David Martinez'
#  'Bryan Herrera' 'Cathy Robinson' 'Dr. William Warren' 'Brian Lee'
#  'Christopher Smith' 'Denise Mccann' 'Melissa Martinez' 'Katherine Salas'
#  'Julie Alexander' 'Anthony Everett' 'Rodney Morales' 'Mark Brown'
#  'Justin Torres' 'Bailey Duran DDS' 'Courtney Mills' 'Jeremy Dalton'
#  'Elizabeth Oliver DDS' 'Theresa Clark' 'Matthew Moore' 'Benjamin Smith'
#  'Kirk Carter' 'Michael Warner' 'Michael Bradshaw' 'Lori Guerrero'
#  'Jessica Stephens' 'Susan Serrano' 'Christopher Parker' 'Laura Roberts'
#  'Michael Lyons' 'Kathryn Snyder' 'Andrew Reynolds' 'David Davis'
#  'Sara Johnston' 'Yvonne Chambers' 'Andrew Avila' 'Matthew Moon'
#  'Kevin Walters' 'Brandon Bailey MD' 'Shannon Rivera' 'Donna Landry'
#  'Krista Gibson' 'Frank Cordova' 'Jose Travis' 'Kimberly Gutierrez'
#  'Isaiah Avila' 'Olivia Harris' 'Tanya Kim' 'Barbara Dudley'
#  'Cynthia Moore' 'Kristen Davis' 'Susan Murray MD' 'Kathleen Moran'
#  'Denise Davenport' 'Mrs. Kristen Reyes' 'Katie Suarez' 'Desiree Tyler'
#  'Timothy Romero' 'Diane Evans' 'Yvonne Burns' 'Joshua Reed'
#  'Kimberly Gibson' 'Colin Terry' 'Cynthia Rowe' 'Patrick Thornton'
#  'Jasmin Alvarado' 'Veronica Simpson' 'Jonathan Lawrence'
#  'Shelly Alexander' 'Joyce Bowen' 'Wayne Morgan' 'Marie Christian'
#  'Shannon James' 'Nathan Malone' 'Amanda Jones' 'Tammie Bright'
#  'Jessica Garcia' 'Shelia Wallace' 'Stephanie Williams' 'Elaine Brooks'
#  'Joseph Knight' 'Carolyn Miller' 'Lisa Allen' 'Briana Murray'
#  'David Smith' 'Stephanie Byrd' 'Jeremy Reed' 'Margaret Coleman'
#  'Ryan Gonzalez' 'John Young' 'Laura Haney' 'William Barrett'
#  'Keith Jennings' 'Amber Obrien' 'Tanner Mitchell DDS' 'Heather Fields'
#  'Megan Le' 'Sara Fuller' 'Maria Parker' 'Kevin Oconnor' 'Edward Burgess'
#  'Carlos Ryan' 'Kiara Mcintyre' 'Dawn Summers' 'Dr. Paul Morgan'
#  'Victor Taylor' 'Shannon Ramsey' 'Tracy Ballard' 'Richard Smith'
#  'Jordan Chambers' 'Lauren Carson' 'Ashley Hall' 'Stephen Hoffman'
#  'Connie Brown' 'Susan Turner' 'Charles Shah' 'Johnathan Davis'
#  'Brandy Chavez' 'Natalie Bautista' 'Patrick Moore' 'Brett Burns'
#  'Trevor Johnson' 'Jeremy Sampson' 'Ariana Jennings' 'Vanessa Howard'
#  'Colton Martinez' 'Jordan Bates' 'Linda Smith' 'Dana Martinez'
#  'Andrea Hubbard' 'Daniel Kane' 'Charles Lester' 'Scott Thomas'
#  'David Thompson' 'Allison Smith' 'Cynthia Morris' 'Anthony Harmon'
#  'Nichole Alvarez' 'Kayla Rodriguez' 'Theresa Williams' 'Sharon Boyd'
#  'Victor Brown' 'James Parks' 'Theodore Jones Jr.' 'Ana Hill'
#  'Kimberly Nguyen' 'Kerry Chavez DDS' 'Michael Farrell' 'Patricia Le'
#  'Jesse Perez' 'Jesse Perry' 'Jeffery Ortega' 'Christian Leblanc'
#  'Ronald Davis' 'Parker Cain' 'Laurie Hoffman' 'Bryan Gomez'
#  'Nicole Parrish' 'Tracy Burke' 'Kenneth Lewis' 'Courtney Rodriguez'
#  'Holly Farmer' 'Renee Bruce' 'Sabrina Austin' 'Allison Hickman'
#  'Debra White' 'Ellen Morgan' 'Sergio Knight' 'Charles Schultz'
#  'Paul Lewis' 'Glen Wood' 'Paula Bradley' 'Anthony Moore' 'Megan Nelson'
#  'Karla Ramos' 'Paul Wilson' 'Douglas Gregory' 'Mr. Andrew Foster'
#  'Aimee Turner' 'Chad Scott' 'Adam Burgess' 'James Padilla' 'Sandra Drake'
#  'Scott Williams' 'Thomas Atkins' 'Laura Mckinney' 'Brian Smith'
#  'Robert Montgomery' 'Tamara Davis' 'Dana Chapman' 'Jennifer Collins'
#  'Gary Jackson' 'Ashley Hicks' 'Hannah Luna' 'Robin Young'
#  'Craig Morrison' 'Mary Thompson' 'Kathleen Webster' 'Joann Glass'
#  'Madison Weber' 'Lori Hernandez' 'Jeremy Turner' 'Anthony Romero'
#  'Jesse Brown' 'Angela Lin' 'Lisa Hunter' 'Julian Conner' 'Joanna Pacheco'
#  'Erica Alvarez' 'Antonio Garcia' 'Gwendolyn Klein' 'Carrie Wright'
#  'Jeffrey Mills' 'Jake Campbell' 'George Harper' 'Maria Jones'
#  'Michael Mitchell' 'Mary Escobar' 'Felicia Aguilar' 'Gregory Ponce'
#  'Jenna Larson' 'Emily Bennett' 'Robin Santiago' 'Nancy Jennings'
#  'Maria Henderson' 'Jack White' 'Travis Tucker' 'Chad Jones' 'Ashley Wise'
#  'Sophia Johnson' 'Ralph Anderson' 'Christopher Guerra' 'Rhonda Martin'
#  'Jason Rhodes' 'Jeremy Mitchell' 'Joann Ferguson' 'Robert Harrison'
#  'Holly Valentine' 'Mrs. Diane Reyes' 'Tracy Montoya' 'Brenda Wright'
#  'Shelly Spencer' 'Ryan Rosales' 'Phillip Nelson' 'Brittany Kim'
#  'Courtney Hayes' 'Alexander Brown' 'Cynthia Vang' 'Alfred Galvan'
#  'Marie Moody' 'Dustin Gallegos' 'Brenda Thornton' 'Aaron Miller'
#  'Ruben Dunn' 'Kelsey Rodriguez' 'Eric Williams' 'Riley Bryant'
#  'Taylor Carlson' 'Jose Allen' 'Jeffrey Mendez' 'Jason Beck'
#  'William Jones' 'Katie Mcneil' 'Jeanette Harrison' 'Veronica King'
#  'Richard Cooper' 'Lori Ingram' 'Evelyn Williams' 'Robin Thompson'
#  'Julie Dominguez' 'Robin Brown' 'Judith Carter' 'Curtis Williams'
#  'Kaylee Hays' 'Dawn Mullins' 'Howard Norman' 'Evelyn Martinez'
#  'Steve Paul' 'Jasmine Beltran' 'Jonathan Glass MD' 'Monica Miller'
#  'Samantha Gardner' 'Bobby Guerrero' 'Lance Simmons' 'Heather Williams'
#  'Heather Bolton' 'William Gould' 'Mark Cox' 'Meghan Cisneros'
#  'Lawrence Harrington' 'Austin Osborne' 'James Bradley' 'Meghan Rush'
#  'Phillip Berry' 'Jennifer Banks' 'Brian Fitzgerald'
#  'Mr. Justin Green III' 'Zachary Mitchell' 'Katherine Martinez'
#  'Jodi Roach' 'Brandon Fleming' 'Emma Reed' 'Joshua Vance' 'Michelle Ho'
#  'Rebecca Hicks' 'Curtis Taylor' 'Allison Spencer' 'Robert Arnold'
#  'Angelica Parker' 'Dr. Kelly Hammond DVM' 'William Day' 'Michael Cooper'
#  'Penny Bowman' 'Vincent Reynolds' 'Amy Martinez' 'Christopher Morris'
#  'Hannah Everett' 'Sarah King' 'Krista Martinez' 'Joseph Shaw'
#  'Todd Moore' 'Michelle Jacobs' 'Kristy Bryan' 'Angel May' 'Marilyn Wang'
#  'Mark Jimenez' 'Donna Frye' 'Dr. Michael Evans' 'Anthony Gonzales'
#  'Mr. Lawrence Edwards' 'Morgan Valencia' 'Bianca Wood' 'Emma Owens'
#  'James Gilbert' 'Sean Moore' 'Kenneth Edwards' 'Kathleen Robertson'
#  'Mr. Alexander Landry MD' 'Cindy Gomez' 'Johnny Khan' 'Julie Herrera'
#  'Jessica Khan' 'Pamela Diaz' 'Kelly Lee' 'Angel Gordon' 'Diana Hays'
#  'Barbara Hester' 'Robert Morgan' 'Nicole Gonzalez' 'Kathryn Williams'
#  'Gary Wells' 'Larry Robertson' 'Louis Martin' 'Nancy Evans MD'
#  'Kim Erickson' 'Robert Richardson' 'Veronica Silva' 'Molly Watts'
#  'John Coffey' 'Paula Lane' 'Lauren Jackson' 'Lisa Randall'
#  'Michael Johnson' 'Ashley Smith' 'Christian Vaughn' 'Reginald Knapp'
#  'Nancy Brown' 'Daniel Nguyen' 'Kelly Edwards' 'Thomas Peterson'
#  'Raymond Le' 'Melissa Bishop' 'David Grant' 'William Evans' 'Daniel Bush'
#  'Gregory Peck' 'Denise Martinez' 'Jamie Baird' 'Tina Ballard'
#  'Dwayne Klein' 'Jeremy Scott' 'Dale Ryan' 'Melissa Taylor'
#  'Laurie Sanchez' 'Kiara Little' 'Jason Love' 'Randy Smith'
#  'Tanya Russell' 'Sherry Woods' 'Victor Morris' 'Susan Davis'
#  'Kimberly Sharp' 'Susan Thompson' 'Casey Gillespie'
#  'Jennifer Simpson DVM' 'Tammy Mcdowell' 'Keith Rodriguez'
#  'Mrs. Virginia Daniels' 'Todd Rosales MD' 'Brian Martin' 'David Lopez'
#  'Rachel Bradley' 'Casey Chase' 'Samantha Robertson' 'Michael Lopez'
#  'Franklin Wright' 'David Molina' 'Elizabeth Sharp' 'Matthew Schwartz'
#  'Bryan Parker' 'Jonathan Jacobson' 'Emily Wilson' 'Elizabeth Mendez'
#  'Casey Hernandez' 'Lisa Perry' 'Kaitlin Medina' 'Colleen Wright'
#  'Shelley Miller' 'Michael Miller' 'Amy Kelley' 'Laura Hernandez'
#  'Joseph Wilson' 'Kevin Davis' 'Rhonda Chavez' 'Joyce Brown'
#  'Robert Cummings' 'Robert Reese' 'Amber Cooper' 'Zachary Michael'
#  'Timothy Johnson' 'Randy Cannon' 'Maria Fisher' 'Janet Kane DVM'
#  'Michael Stanley' 'Martha Bailey' 'Joshua Rice' 'Courtney Smith'
#  'Edwin Nunez' 'Kim Morrow' 'Gregory Hill' 'Molly Rodriguez'
#  'Jennifer Miranda' 'Alexis Harris' 'Andrew Harper' 'Amber Yang'
#  'David Robinson' 'Amy Gordon' 'Robert Dennis' 'Kyle Chambers'
#  'Eric Thomas' 'Connie Turner' 'Travis Hobbs' 'Lori Simmons'
#  'William David DDS' 'Emma Butler' 'James Webster' 'Samuel Turner'
#  'Renee Melendez' 'Tracy Grant' 'David Harris' 'Tammy Boone'
#  'Nathaniel Lee' 'Michael Morrison' 'Chelsea Gill' 'Kristin Mendoza'
#  'Felicia Krueger' 'Timothy Hayden' 'Zachary Mendoza' 'Larry Harris'
#  'Kristen Rowe' 'Joseph Howard' 'Jose Crawford' 'William Harrison'
#  'Suzanne Wood' 'Justin Walker' 'Dean Donovan' 'Jennifer Hernandez'
#  'James Whitaker' 'Mr. Michael Scott PhD' 'Maria Henry' 'Robert Jackson'
#  'Katherine Stark' 'Maria Brown' 'Ryan Landry' 'Pamela Gutierrez'
#  'Crystal Mann' 'Jonathan Brooks' 'Mary Jensen' 'Mr. Aaron Arnold'
#  'Joseph Hill' 'Alicia Li' 'Renee Browning' 'Brent Hernandez'
#  'Joseph Ochoa' 'James Watson' 'Karl Branch' 'Michael Abbott'
#  'Shannon Malone' 'James Tran' 'Adam Jackson' 'Mr. Richard Knight PhD'
#  'Joseph Williams' 'Sean Clay' 'Anthony Jones' 'Stephanie Elliott'
#  'Timothy Edwards' 'Laurie Goodwin' 'Jennifer Jones' 'David Davenport'
#  'Steven Rivera' 'Brenda Hinton' 'Kathryn Mccann' 'Jeffrey Roberson'
#  'Randy Friedman' 'Raymond Johnson' 'Willie Henry' 'Todd Reynolds'
#  'Mary Miller' 'Rebecca Marquez' 'Christian Dawson' 'Nancy Stewart'
#  'Aaron Parker' 'Derrick Anderson' 'Jerry Peters' 'Alexander Gomez'
#  'Kyle Nguyen' 'Edgar Hughes' 'Steven Stein' 'Laura Jackson'
#  'Charles Turner' 'Arthur Hamilton MD' 'Mr. David Wright' 'Linda Gonzalez'
#  'Eric Rush' 'Manuel Brock' 'George Ochoa' 'Valerie Taylor'
#  'Travis Harris' 'Vincent Novak' 'Michael Henry' 'Dana Bennett'
#  'Jenna Wilson' 'Leslie Gardner' 'Krista Benton' 'Michael Gonzales'
#  'Michael Fuentes' 'Jennifer Porter' 'Dana Hopkins' 'Rachel Jones'
#  'Karen Morales DDS' 'Melissa Stephens' 'Heather Woodard'
#  'Margaret Miller' 'Mary Kelly' 'Amanda Terrell' 'Jennifer Goodwin'
#  'Jessica Smith' 'Jorge Stone' 'Laura Griffin' 'Raymond Chapman'
#  'Haley Johnson' 'Jason Nixon' 'Todd Thomas' 'Jesse Clark'
#  'Mr. Jeffrey Horton' 'Eric Patrick' 'Samuel Wong' 'Carly Riggs'
#  'Christopher Moore' 'Tina Hall' 'Cody Davidson' 'Allen Mendez'
#  'Kevin Price' 'Christine Goodwin' 'Amy Garcia' 'Chelsea Nguyen'
#  'Dennis Huffman' 'Margaret Harper' 'Laurie Bailey' 'Lisa Cervantes'
#  'Cesar Wilson' 'Clayton Steele' 'Jennifer Taylor' 'Cody Reid'
#  'Maria Cooke' 'Katherine Taylor' 'Jerry Brown' 'Adam Taylor'
#  'Tracey Wagner' 'Michael Perry PhD' 'Bradley Johnson DDS' 'Donald Medina'
#  'Jim Newton' 'Krista Wilson' 'Reginald Morrow' 'Rodney Williams'
#  'Kimberly Fritz' 'Ronald Potter' 'Zachary Cole' 'Robert Gonzales'
#  'Patricia Young PhD' 'Heather Page' 'Carol Taylor' 'Daniel Brown'
#  'Douglas Ryan' 'Michael Roberts' 'Scott Duke' 'Anna Estes'
#  'Tamara Riddle' 'Beth Cline' 'Michael Poole' 'Megan Burns' 'Debra Perry'
#  'Mark Beard' 'Jose Ramirez' 'Jackie Clements' 'Aaron Schroeder'
#  'Monica Ellis' 'Heather Brown' 'Claudia Jordan' 'Derrick Clayton'
#  'Kenneth Knight' 'Mr. Michael Williams' 'Richard Stevens'
#  'Scott Alexander' 'Tyler Harris' 'Bonnie Santos' 'Timothy Hill'
#  'Danielle Watson' 'Carol Sanders' 'Michael Young' 'Michele Smith'
#  'Casey Perez' 'Alexandra Dominguez' 'Virginia Henderson' 'Benjamin Reyes'
#  'Ashley Edwards' 'Breanna Ayala' 'Brandi Haney' 'Joseph Smith'
#  'Jessica Bowen' 'Brittany Jenkins' 'Shannon Miller' 'Paul Lawrence'
#  'Victor Edwards' 'Donald Miller' 'Lindsay Lawson' 'Melissa Abbott'
#  'Elizabeth Holmes' 'Nicole Phillips' 'Steven Blevins' 'Brian Porter MD'
#  'Vanessa Hatfield' 'Bonnie Valencia' 'Holly Vega' 'Tiffany Townsend'
#  'Austin Baker' 'Antonio Mccormick' 'Lori Mason' 'Lisa Ramirez'
#  'Jorge Harris' 'Kimberly Myers' 'Sandra Becker' 'Michael Blair'
#  'Amy Miller' 'Jesse Lynch' 'Patrick Yang' 'Michael Miles' 'Troy Mills'
#  'Michelle Jackson' 'Richard Adams' 'Patricia Johnson' 'Denise Brown'
#  'Laura Jones' 'Ian Porter' 'Holly Scott' 'Kenneth Sharp'
#  'Jordan Williams' 'Dana Ruiz' 'Chris Velazquez' 'Kristen Sloan'
#  'Jennifer Morris' 'Nathan Nelson' 'Jake Shaw' 'Cassie Brock'
#  'Dr. Andrea Marshall' 'Ryan Murphy' 'Aimee Gonzalez' 'Elizabeth Dean'
#  'Kevin Snyder' 'Christie Mccullough' 'Danielle Smith' 'David Reed'
#  'Sherry Tapia' 'Matthew Sweeney' 'Ashley Moreno' 'Johnathan Brown'
#  'Michelle Davis DVM' 'Kelly Haynes' 'William Miller' 'Casey Wilkins'
#  'Keith Graham' 'Cynthia Green' 'Robert Haynes' 'Emily Nelson' 'Dale Chan'
#  'Brittney Martin' 'Jason Herrera' 'Christine Parker' 'Bryan Moore'
#  'Samantha Terry' 'Russell Murphy' 'David Kelly' 'Megan Green'
#  'Amanda Sullivan MD' 'Danielle Murray' 'Brenda Smith' 'Vickie Anderson'
#  'Jacqueline Mccoy' 'Lauren Green' 'Alison Brown' 'Jill Anderson'
#  'Sandra Rivera' 'Joel Jackson' 'Samantha Foster' 'Michael Thompson'
#  'Cody Ramirez' 'Amanda Harvey' 'Edward Jenkins' 'Amy Ramirez'
#  'Curtis Wilkerson' 'Lydia Pham' 'Virginia Casey' 'Joshua Washington'
#  'Kathryn Price' 'Francis Robinson' 'Paula Brown' 'Kendra Wang DVM'
#  'Ariel Sandoval' 'Robert Stark' 'Zachary Robinson' 'Rebecca Kelly'
#  'Sarah Thompson' 'Renee Wolfe' 'Alyssa Haynes' 'Kristy Hart'
#  'William Keith' 'Eric Henry Jr.' 'Daniel Fox' 'Thomas Harris'
#  'Mitchell Sellers' 'Erica Johnson' 'Sylvia Schroeder' 'Shannon Yu'
#  'Tom Foster' 'Eric Taylor' 'Travis Conner' 'Marie Thompson'
#  'Melissa Mcfarland' 'Courtney Chapman' 'Eric Barker' 'Nicholas Rush'
#  'Jenna Gamble' 'Amanda Guzman' 'Tracy Walker' 'Taylor Taylor'
#  'Cynthia Haas' 'Stephen Davis' 'Margaret Tanner' 'Derek Wright'
#  'David Rodriguez' 'James Oconnor' 'Stacey Snyder' 'Joshua Garcia'
#  'Sean Curtis' 'Carla Jones' 'Elizabeth Flores' 'Angela Jackson'
#  'Nicholas Payne' 'Anna Wheeler' 'Karen Johnson' 'Carmen Preston'
#  'Brian Harris' 'Michael Bowen' 'Deborah Campbell' 'Anthony Armstrong'
#  'Brittany Ward' 'Edward Stanley' 'Christina Johnson' 'Edgar Miller'
#  'Elizabeth Sanders' 'Matthew Davis MD' 'Stephen Wood' 'Dennis Marshall'
#  'Derrick Brown' 'Joshua Arellano' 'Kristen Randall' 'Jennifer Nichols'
#  'Karen Keith' 'Blake Orr' 'Kathryn Lester' 'Megan Oliver'
#  'Peter Thompson' 'Dr. Rhonda Martinez' 'William Graham' 'Lori Flowers MD'
#  'Suzanne Jones' 'James Nguyen' 'Jimmy Marks' 'Lisa Mills'
#  'Jason Hernandez' 'Olivia Ayers' 'Kristine Garcia' 'Joseph Cooper'
#  'James Washington' 'Amanda Hill' 'Lee Steele' 'Steve Rivera'
#  'Patrick Mccall' 'Alicia Roth' 'Douglas Vasquez' 'Annette Melton'
#  'William Ramos' 'Debra Butler' 'Chelsea Lewis' 'Natalie Malone'
#  'Eric Hunter' 'Samuel Suarez' 'Corey Whitaker' 'Danielle Bryant'
#  'Michele Hill' 'Kathy Reid' 'Andre Watson' 'Cassandra Harrell'
#  'Hannah Martin' 'Nicole Barker' 'James Martin' 'Traci Vincent'
#  'Megan Adams' 'Alejandro Deleon' 'Alexa Buck' 'Lindsay Smith'
#  'Robert Torres' 'Maria Coleman' 'Gregory King' 'Michael Holloway'
#  'Brian Hunt' 'Sarah Brooks' 'Lisa Evans' 'Arthur Mcneil' 'Shannon Green'
#  'Stephanie Evans' 'Ralph Yoder' 'Rebekah Greene' 'Melanie Griffith'
#  'Yolanda Green' 'James Johnson' 'Laura Lee' 'Courtney Nichols'
#  'Susan Powers' 'Sarah Pittman' 'Catherine Davis' 'David Stokes'
#  'Catherine Frazier' 'Brandon Kelly' 'Elizabeth French' 'David Carter'
#  'Julie Delacruz' 'Terry Jones' 'Kathryn Dillon' 'Edwin Brown'
#  'Brenda Gonzalez' 'Keith Knox' 'Eugene Baldwin' 'Katherine Welch'
#  'Mark Smith' 'Philip Jackson' 'Katherine Gallagher' 'Lucas Schultz'
#  'Vincent Reyes' 'Curtis Watson' 'Frank Whitaker' 'Michael Sims'
#  'James Chapman' 'Rodney Evans' 'Nicholas Carlson' 'Stephen Cowan'
#  'Steven Howard' 'Travis Hull' 'Darryl Acosta' 'Nicholas Lawrence'
#  'Jacob Santos' 'Shawn Scott' 'Amber Vang' 'Martha Smith' 'Jennifer James'
#  'Kara Hernandez' 'Lorraine Turner']

# %% [markdown]
# 2. **arrival_date**

# %% [markdown]
# Pada kolom ini ditemukan variasi format tanggal yang berbeda. Perbedaan format ini dapat menyebabkan kesalahan dalam analisis waktu, sehingga perlu dilakukan standarisasi format tanggal (misalnya YYYY-MM-DD).

# %%
print(df['arrival_date'].unique())
# Out:
# ['2025-03-16' '2025-12-13' '2025-06-29' '2025-10-12' '2025-02-18'
#  '2025-06-26' '2025-12-26' '2025-05-21' '2025-07-30' '2025-11-01'
#  '2025-01-19' '2025-06-24' '2025-11-15' '2025-02-24' '2025-06-11'
#  '2025-10-15' '2025-11-09' '2025-09-12' '2025-08-27' '2025-04-02'
#  '2025-03-29' '2025-06-14' '2025-11-07' '2025-06-10' '2025-02-05'
#  '2025-10-30' '2025-07-14' '2025-10-20' '2025-02-22' '2025-10-07'
#  '2025-02-28' '2025-04-25' '2025-08-25' '2025-10-05' '2025-01-29'
#  '2025-12-22' '2025-04-27' '2025-09-25' '2025-07-09' '2025-07-12'
#  '2025-05-29' '2025-06-13' '2025-10-16' '2025-08-15' '2025-12-31'
#  '2025-03-14' '2025-08-05' '2025-02-08' '2025-04-12' '2025-02-13'
#  '2025-08-04' '2025-08-03' '2025-01-25' '2025-09-23' '2025-03-27'
#  '2025-11-11' '2025-04-13' '2025-04-18' '2025-06-20' '2025-12-30'
#  '2025-07-29' '2025-09-04' '2025-04-06' '2025-08-24' '2025-12-25'
#  '2025-11-20' '2025-07-06' '2025-07-17' '2025-11-29' '2025-09-17'
#  '2025-03-04' '2025-08-29' '2025-09-18' '2025-04-09' '2025-03-03'
#  '2025-03-09' '2025-11-19' '2025-01-09' '2025-08-14' '2025-09-08'
#  '2025-02-06' '2025-03-22' '2025-11-14' '2025-12-20' '2025-06-17'
#  '2025-10-31' '2025-06-30' '2025-07-07' '2025-09-06' '2025-06-09'
#  '2025-03-23' '2025-01-12' '2025-06-04' '2025-12-10' '2025-03-15'
#  '2025-03-01' '2025-12-18' '2025-09-27' '2025-02-02' '2025-02-27'
#  '2025-01-27' '2025-01-21' '2025-09-14' '2025-06-12' '2025-10-01'
#  '2025-11-05' '2025-02-19' '2025-01-15' '2025-09-30' '2025-03-05'
#  '2025-01-11' '2025-06-28' '2025-02-15' '2025-07-21' '2025-03-18'
#  '2025-07-13' '2025-05-02' '2025-09-19' '2025-07-23' '2025-07-27'
#  '2025-01-03' '2025-10-28' '2025-02-04' '2025-07-26' '2025-12-16'
#  '2025-01-24' '2025-01-18' '2025-12-21' '2025-01-14' '2025-02-10'
#  '2025-05-10' '2025-12-11' '2025-08-17' '2025-01-10' '2025-04-03'
#  '2025-10-03' '2025-04-17' '2025-04-29' '2025-08-11' '2025-12-06'
#  '2025-01-08' '2025-09-21' '2025-08-06' '2025-05-25' '2025-03-17'
#  '2025-05-22' '2025-08-08' '2025-10-06' '2025-11-06' '2025-03-06'
#  '2025-11-12' '2025-08-12' '2025-09-24' '2025-09-22' '2025-08-09'
#  '2025-09-28' '2025-12-02' '2025-07-22' '2025-02-21' '2025-06-05'
#  '2025-06-07' '2025-05-12' '2025-12-17' '2025-06-08' '2025-09-20'
#  '2025-06-22' '2025-10-04' '2025-06-01' '2025-08-30' '2025-05-23'
#  '2025-09-11' '2025-05-05' '2025-10-29' '2025-02-11' '2025-07-15'
#  '2025-03-08' '2025-10-27' '2025-10-14' '2025-05-01' '2025-05-16'
#  '2025-03-25' '2025-08-19' '2025-05-31' '2025-10-18' '2025-05-14'
#  '2025-03-07' '2025-07-25' '2025-10-08' '2025-01-20' '2025-09-10'
#  '2025-03-24' '2025-09-09' '2025-02-09' '2025-11-04' '2025-04-26'
#  '2025-09-03' '2025-11-10' '2025-01-13' '2025-12-04' '2025-07-02'
#  '2025-04-30' '2025-02-17' '2025-08-02' '2025-12-09' '2025-03-28'
#  '2025-08-20' '2025-05-18' '2025-06-18' '2025-05-20' '2025-09-26'
#  '2025-06-02' '2025-06-21' '2025-09-15' '2025-10-10' '2025-07-08'
#  '2025-07-05' '2025-04-14' '2025-04-22' '2025-08-22' '2025-08-18'
#  '2025-02-07' '2025-04-19' '2025-08-16' '2025-02-16' '2025-11-21'
#  '2025-06-23' '2025-04-16' '2025-07-01' '2025-01-07' '2025-09-05'
#  '2025-07-18' '2025-05-11' '2025-01-17' '2025-01-22' '2025-05-24'
#  '2025-10-11' '2025-10-24' '2025-12-29' '2025-05-09' '2025-06-25'
#  '2025-05-08' '2025-12-19' '2025-06-03' '2025-10-13' '2025-05-19'
#  '2025-07-31' '2025-05-28' '2025-08-07' '2025-05-27' '2025-07-20'
#  '2025-08-10' '2025-05-07' '2025-11-28' '2025-12-28' '2025-12-07'
#  '2025-11-03' '2025-08-13' '2025-11-27' '2025-02-20' '2025-09-16'
#  '2025-01-02' '2025-12-23' '2025-10-21' '2025-05-26' '2025-01-23'
#  '2025-06-16' '2025-05-06' '2025-04-23' '2025-09-02' '2025-05-04'
#  '2025-03-10' '2025-12-08' '2025-04-11' '2025-01-05' '2025-07-11'
#  '2025-11-25' '2025-10-25' '2025-11-23' '2025-10-19' '2025-03-13'
#  '2025-07-03' '2025-11-17' '2025-07-10' '2025-10-17' '2025-04-04'
#  '2025-01-16' '2025-11-22' '2025-08-23' '2025-04-28' '2025-12-03'
#  '2025-04-21' '2025-02-14' '2025-06-06' '2025-03-20' '2025-01-04'
#  '2025-05-13' '2025-03-31' '2025-10-09' '2025-12-27' '2025-03-19'
#  '2025-01-06' '2025-03-11' '2025-04-01' '2025-12-15' '2025-11-13'
#  '2025-09-29' '2025-02-01' '2025-12-05' '2025-11-16' '2025-03-21'
#  '2025-04-05' '2025-11-18' '2025-04-08' '2025-07-28' '2025-02-25'
#  '2025-04-24' '2025-07-04' '2025-05-15' '2025-03-02' '2025-08-01'
#  '2025-11-08' '2025-01-30' '2025-10-22' '2025-09-13' '2025-10-26'
#  '2025-07-16' '2025-01-26' '2025-05-30' '2025-06-15' '2025-01-31'
#  '2025-03-30' '2025-11-24' '2025-05-17' '2025-01-28' '2025-09-01'
#  '2025-04-07' '2025-09-07' '2025-04-10' '2025-12-12' '2025-03-26'
#  '2025-08-31' '2025-02-12' '2025-03-12' '2025-12-14']

# %% [markdown]
# 3. **Daparture_date**

# %% [markdown]
# Terdapat potensi nilai tidak konsisten akibat perbedaan format tanggal dan kemungkinan kesalahan logika waktu, seperti tanggal keluar lebih awal dari tanggal masuk. Data tersebut perlu diperbaiki atau dihapus karena dapat menyebabkan kesalahan perhitungan lama tinggal pasien

# %%
print(df['departure_date'].unique())
# Out:
# ['2025-03-22' '2025-12-14' '2025-07-05' '2025-10-23' '2025-02-25'
#  '2025-06-30' '2025-12-27' '2025-06-04' '2025-08-13' '2025-11-14'
#  '2025-01-21' '2025-06-26' '2025-11-19' '2025-03-03' '2025-06-23'
#  '2025-10-17' '2025-11-16' '2025-09-25' '2025-09-01' '2025-04-10'
#  '2025-04-12' '2025-06-20' '2025-11-09' '2025-06-17' '2025-02-18'
#  '2025-11-04' '2025-07-21' '2025-10-26' '2025-03-06' '2025-10-08'
#  '2025-03-14' '2025-04-26' '2025-09-03' '2025-10-16' '2025-02-11'
#  '2025-12-31' '2025-05-07' '2025-11-15' '2025-07-19' '2025-07-15'
#  '2025-06-09' '2025-06-14' '2025-03-04' '2025-08-19' '2026-01-11'
#  '2025-03-23' '2025-08-18' '2025-04-14' '2025-02-24' '2025-11-08'
#  '2025-08-07' '2025-08-08' '2025-01-27' '2025-03-10' '2025-09-30'
#  '2025-04-06' '2025-05-04' '2025-11-18' '2025-04-30' '2025-06-28'
#  '2026-01-06' '2025-07-30' '2025-11-10' '2025-09-17' '2025-04-09'
#  '2025-02-12' '2025-09-02' '2025-09-05' '2025-12-29' '2025-06-29'
#  '2025-11-22' '2025-07-17' '2025-07-16' '2025-07-24' '2025-12-01'
#  '2025-09-28' '2025-09-08' '2025-09-24' '2025-04-13' '2025-08-21'
#  '2025-11-30' '2025-07-23' '2025-01-17' '2025-08-22' '2025-09-13'
#  '2025-03-24' '2025-11-27' '2025-12-28' '2025-10-22' '2025-07-10'
#  '2025-07-14' '2025-09-09' '2025-03-27' '2025-01-19' '2025-06-05'
#  '2025-12-23' '2025-03-15' '2025-12-22' '2025-01-18' '2025-07-18'
#  '2025-10-10' '2025-02-08' '2025-02-15' '2025-01-30' '2025-01-26'
#  '2025-06-13' '2025-10-13' '2025-11-13' '2025-02-23' '2025-07-08'
#  '2025-01-24' '2025-10-14' '2025-11-21' '2025-03-18' '2025-10-15'
#  '2025-04-21' '2025-07-06' '2025-02-21' '2025-07-29' '2025-10-25'
#  '2025-07-31' '2025-01-12' '2025-10-31' '2026-01-04' '2025-10-18'
#  '2025-08-05' '2025-02-17' '2025-07-27' '2025-12-21' '2025-01-28'
#  '2026-01-13' '2025-02-20' '2025-04-29' '2025-09-26' '2025-05-17'
#  '2025-12-20' '2025-01-13' '2025-10-11' '2025-03-11' '2025-04-22'
#  '2025-11-02' '2025-10-24' '2025-05-02' '2025-06-11' '2025-12-13'
#  '2025-01-10' '2025-10-04' '2025-03-29' '2025-08-17' '2025-03-28'
#  '2025-05-27' '2025-08-10' '2025-06-19' '2025-03-19' '2025-01-25'
#  '2025-10-09' '2025-11-25' '2025-09-27' '2025-11-05' '2026-01-10'
#  '2025-12-07' '2025-07-25' '2025-03-07' '2025-06-08' '2025-05-22'
#  '2025-06-15' '2025-07-02' '2025-06-02' '2025-02-27' '2025-09-04'
#  '2025-05-30' '2025-05-26' '2025-09-20' '2025-05-12' '2025-11-01'
#  '2025-07-28' '2025-02-01' '2025-11-06' '2025-05-08' '2025-05-20'
#  '2026-01-03' '2025-03-31' '2025-08-20' '2025-08-27' '2025-09-15'
#  '2025-07-13' '2025-05-29' '2025-02-28' '2025-01-23' '2025-10-21'
#  '2025-02-07' '2025-01-29' '2025-04-18' '2025-01-22' '2025-06-22'
#  '2025-10-02' '2025-09-18' '2025-04-02' '2025-09-10' '2025-02-10'
#  '2025-05-10' '2025-04-08' '2025-04-01' '2025-12-09' '2025-07-07'
#  '2025-03-05' '2025-02-16' '2025-05-09' '2025-03-02' '2025-12-17'
#  '2025-08-30' '2025-08-06' '2025-09-23' '2025-05-24' '2025-02-22'
#  '2025-06-27' '2025-05-31' '2025-10-01' '2025-10-27' '2025-09-29'
#  '2025-06-10' '2025-06-24' '2025-05-06' '2026-01-09' '2025-08-23'
#  '2025-10-12' '2025-07-09' '2025-04-27' '2025-04-17' '2025-05-05'
#  '2025-01-31' '2025-08-04' '2025-05-01' '2025-09-21' '2025-08-26'
#  '2025-07-11' '2025-09-16' '2025-05-18' '2025-06-12' '2026-01-01'
#  '2025-03-16' '2025-12-18' '2025-05-21' '2025-08-25' '2025-04-16'
#  '2025-09-14' '2025-10-28' '2025-05-16' '2025-09-06' '2025-05-19'
#  '2025-08-11' '2025-07-01' '2025-12-12' '2025-08-24' '2025-08-01'
#  '2025-08-14' '2025-04-19' '2025-04-07' '2025-08-03' '2025-05-14'
#  '2025-08-02' '2025-12-04' '2025-03-30' '2025-09-22' '2025-06-03'
#  '2025-04-25' '2025-12-10' '2025-02-26' '2025-01-15' '2025-12-24'
#  '2025-06-18' '2025-07-20' '2025-02-13' '2025-10-03' '2025-12-15'
#  '2025-04-15' '2025-01-06' '2025-11-12' '2025-07-12' '2025-08-09'
#  '2025-08-31' '2025-12-03' '2025-07-22' '2025-02-19' '2025-06-01'
#  '2025-03-25' '2025-10-19' '2025-11-23' '2025-02-06' '2025-06-25'
#  '2025-01-14' '2025-02-04' '2026-01-07' '2025-03-20' '2025-09-12'
#  '2025-02-09' '2025-04-03' '2025-12-19' '2025-01-07' '2025-11-17'
#  '2025-11-03' '2025-02-05' '2025-12-16' '2025-10-30' '2025-08-15'
#  '2025-12-08' '2025-06-16' '2025-12-02' '2025-05-25' '2025-11-24'
#  '2025-03-26' '2025-03-08' '2025-01-20' '2025-05-28' '2025-04-23'
#  '2025-03-12' '2025-05-03' '2025-06-21' '2026-01-02' '2025-08-12'
#  '2025-01-09' '2025-10-29' '2025-11-07' '2025-09-19' '2025-03-09'
#  '2025-05-15' '2025-11-26' '2025-10-06' '2025-10-20' '2025-05-23'
#  '2025-11-29' '2026-01-05' '2025-01-08' '2025-07-03' '2025-06-07'
#  '2025-04-28' '2025-06-06']

# %% [markdown]
# 4. **Service**

# %% [markdown]
# Kolom Service biasanya kategori layanan, inconsistency terjadi karena
# Penulisan berbeda, Singkatan, dan Typo.

# %%
print(df['service'].unique())
# Out:
# ['surgery' 'general_medicine' 'emergency' 'ICU']

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Missing values adalah data yang kosong atau tidak terisi (NULL/NaN).
# Pada tahap ini bisa melihat berapa banyak daya yang kosong.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['non-null'])
# Out:
#                 non-null
# patient_id           0.0
# name                 0.0
# age                  0.0
# arrival_date         0.0
# departure_date       0.0
# service              0.0
# satisfaction         0.0

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Duplicate values adalah baris data yang sama persis muncul lebih dari satu kali. hal ini dilakukan Dataset bebas dari redundansi data sehingga analisis tidak bias.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [patient_id, name, age, arrival_date, departure_date, service, satisfaction]
# Index: []

# %% [markdown]
# Pada data ini, Setiap Patient_ID bersifat unik. Tidak ditemukan baris data yang identik secara keseluruhan.

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# nilai yang jauh berbeda dari sebagian besar data dan dapat mempengaruhi hasil analisis.
# * Kolom Age
#
# Ditemukan usia sangat rendah (0 tahun) dan sangat tinggi (hingga 89 tahun).
# Nilai ini masih logis karena mencerminkan pasien bayi dan lansia.
#
# * Kolom Length_of_Stay
#
# Terdapat pasien dengan lama rawat inap jauh lebih lama dibanding pasien lain.
# Hal ini bisa terjadi pada pasien dengan penyakit kronis atau komplikasi serius.
#
# * Kolom Satisfaction
# Nilai kepuasan berada pada rentang normal (60–99), sehingga tidak ditemukan outlier ekstrem.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom         Persentase Outliers
# age                           0.0
# satisfaction                  0.0

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['age'])
plt.title('Boxplot of age')
plt.ylabel('age')
plt.show()

# %% [markdown]
# #**Eksplorassi Data (EDA)**

# %% [markdown]
# #**Comparison(Perbandingan)**

# %% [markdown]
# Comparison digunakan untuk membandingkan dua atau lebih kategori atau kelompok data.
#
# Tujuannya: Mengetahui kategori mana yang paling dominan, Membandingkan performa atau jumlah antar kelompok
#
# Contoh visuanya, Bar Chart:
# * rata-rata length_of_stay per dapartemen
# * rata-rata statisfaction per gender

# %%
age_departure_date = df.groupby('departure_date')['age'].count().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=age_departure_date.index, y=age_departure_date.values, palette='viridis', hue=age_departure_date.index, legend=False)
plt.title('age Berdasarkan departure_date')
plt.xlabel('departure_date')
plt.ylabel('age')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #**Composition(Komposisi)**

# %% [markdown]
# Composition adalah analisis untuk melihat proporsi atau persentase bagian dalam satu keseluruhan.
# Biasanya menggunakan pie chart atau stacked bar chart.  Tujuannya yaitu:
# * Mengetahui kontribusi tiap kategori terhadap total data
# * Melihat struktur data secara keseluruhan.
#
# Visualnya yaitu Pie Chart atau Bar Chart:
# * Persentase Gender
# * Persentase Admission_Type
# * Persentase Department

# %%
sales_by_service = df.groupby('service')['age'].sum().sort_values(ascending=False)
sales_by_service_top3 = sales_by_service.head(3)

plt.figure(figsize=(10, 8))
sales_by_service_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Kategori Teratas Berdasarkan Total data')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# #**Distribution(Distribusi)**

# %% [markdown]
# Distribution adalah analisis untuk melihat sebaran nilai numerik.
# Biasanya menggunakan histogram atau boxplot.
#
# Tujuannya:
# * Mengetahui pola data (normal, miring, dll)
# * Melihat nilai ekstrem (outliers)
# * Mengetahui rentang dan sebaran data
#
# contoh visualnya
# Histogram atau Boxplot:
# * Distribusi Age
# * Distribusi Length_of_Stay
# * Distribusi Satisfaction

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Distribusi (age)')
plt.xlabel('age')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #**Relationship(Hubungan)**

# %% [markdown]
# analisis untuk melihat hubungan antara dua atau lebih variabel.
# Biasanya menggunakan scatter plot atau correlation heatmap.
# Tujuan:
# * Mengetahui variabel yang saling mempengaruhi
# * Mencari pola atau korelasi dalam data
# Visualnya:
# Scatter Plot atau Heatmap Korelasi:
# * Age vs Length_of_Stay
# * Length_of_Stay vs Satisfaction

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['age', 'satisfaction']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara age dan satisfaction')
plt.show()

# %% [markdown]
# #**Data Preparation**

# %% [markdown]
# ##**Penanganan Type Data**

# %% [markdown]
# **1. Departure Date**

# %%
df["departure_date"] = pd.to_datetime(df["departure_date"], format="mixed")
df["departure_date"].head(5)
# Out:
# 0   2025-03-22
# 1   2025-12-14
# 2   2025-07-05
# 3   2025-10-23
# 4   2025-02-25
# Name: departure_date, dtype: datetime64[ns]

# %% [markdown]
# **2. Arrival Date**

# %%
df["arrival_date"] = pd.to_datetime(df["arrival_date"], format="mixed")
df["arrival_date"].head(5)
# Out:
# 0   2025-03-16
# 1   2025-12-13
# 2   2025-06-29
# 3   2025-10-12
# 4   2025-02-18
# Name: arrival_date, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   object
#  1   name            1000 non-null   object
#  2   age             1000 non-null   int64
#  3   arrival_date    1000 non-null   datetime64[ns]
#  4   departure_date  1000 non-null   datetime64[ns]
#  5   service         1000 non-null   object
#  6   satisfaction    1000 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 54.8+ KB

# %% [markdown]
# Jadi diatas ada data yang salah, yaitu seharusnya tipe datanya berupa datetime, tetapi malah object, maka dibawah ini menggunakan penanganan type data untuk memperbaikinya.

# %% [markdown]
# #**Incosistent values**

# %% [markdown]
# Tahap penanganan Inconsistent Values tidak diperlukan karena memang dalam dataset ini sudah konsisten, tidak ada bermasalah tau pun kenapa napa,nskema datanya stabil, tidak ada yang perlu baikin lagi.

# %% [markdown]
# #**Massing value**

# %% [markdown]
# Penanganan Misssing Values tidak diperlukan, karena
# Data tidak ada yang hilang datanya sangat lengkap, integrasi datanya sempurna.
# - Efisiensi alur kerja tetap ringkas tanpa langkah redundan yang tidak memberikan perubahan pada kualitas data
# - Data derasal dari sumber terverifikasi

# %% [markdown]
# #**Duplicated Values**
# Tidak ada yang terduplikat, atau data nya ganda di data saya, dengan data bersih ini, menjadi efisiensi komputasi.

# %% [markdown]
# #**Outliers**

# %% [markdown]
# - Data Masih dalam Rentang Logis
# - Keandalan Sumber Data
# Karna edata berasal dari sistem yang sudah terverifikasi, nilai-nilai ekstrem yang muncul diperlakukan sebagai fakta lapangan (kejadian nyata), bukan sebagai kesalahan input atau noise yang harus dibuang.
# Dataset ini sangat bersih. Tidak ada data "sampah" seperti usia 200 tahun atau skor kepuasan 500. Satu-satunya yang perlu dipastikan adalah apakah usia 0 itu valid untuk unit layanan yang bersangkutan (misal: ICU atau Emergency)

# %% [markdown]
# ##**Kontruksi Data (Contruct Data)**

# %% [markdown]
# Saya tidak menggunakan kontruksi data ini karena data saya sudah memenuhi kebutuhan analisis kolom-kolom yang ada saat ini sudah cukup untuk menjawab pertanyaan riset atau tujuan bisnis ini. data ini sudah memiliki header yang jelas di baris pertama. Karena nama kolomnya sudah standar (seperti id, nama, diagnosis), sistem tidak perlu lagi dikonstruksi ulang untuk mengenali jenis informasinya.

# %% [markdown]
# ##**Reduksi Data (Data Reduction)**

# %% [markdown]
# Reduksi data biasanya dilakukan jika ukuran file mencapai Gigabyte atau Terabyte yang memberatkan memori. Karena file patients.csv saya ukurannya relatif kecil (skala kilobyte/megabyte), proses reduksi justru akan membuang-buang waktu (overhead) tanpa memberikan peningkatan performa yang signifikan.
# melakukan reduksi berisiko menghilangkan korelasi penting yang dibutuhkan untuk analisis mendalam di masa depan. jadi saya ingin menjaga akurasi 100% dari sumber aslinya.Mempertahankan seluruh dimensi dan record data sangat penting untuk menjaga integritas informasi dan menghindari risiko hilangnya variabel prediktor yang krusial bagi analisis medis di tahap selanjutnya.

# %% [markdown]
# #**Menyimpan Dataset**

# %%
df.to_csv('/content/drive/MyDrive/AVD/patients.csv', index=False)
