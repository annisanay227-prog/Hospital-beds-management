# %% [markdown]
# # **HOSPITAL BEDS MANAGEMENT**

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/AVD/patients.csv"
df = pd.read_csv(path)
df
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %% [markdown]
# # **BUSINESS UNDERSTANDING**

# %% [markdown]
# **Business Objective**
#
# Rumah Sakit ini ingin tahu bagaimana cara mengatur staf, tempat tidur dan lyanan agar sesuai dengan jumlah pasien. tujuannya supaya pelayanan lebih lancar, tidak ada kekurangan saf atay tempat tidur, dan pasien bisa ditanganin dengan baik.

# %% [markdown]
# **Assess Situation**

# %% [markdown]
# *   Data tersedi: ada data tentang jumlah pasien, staf dan tempat tidur di tiap layanan/ dapartemen.
# *   Masalah: kadang ada dapartemen yang terlalu sibuk, sementara yang lain lebih longgar.
# *   Kebutuhan: manajemen ingin tau nagian mana yang kekurangan sumber daya.
# *   pihak terkait: direktur rumah sakit, kepala daprtemen, dan tim operasional.

# %% [markdown]
# **Analytic Goals**

# %% [markdown]
# *  Menghitung rasio
# pasien dibandikan staf dan Tempat tidur
# *  Menemukan dapartemen yang paling sibuk
# *   Membuat perkiraan kebutuhan staf jika jumlah pasien meningkat
# *  Menyajikan hasil dalam bentuk grafik atau tabel agar mudah dipahami

# %% [markdown]
# **Project Plan**

# %% [markdown]
# *   Langkah 1: Pahami Data
#
#     Melihatihat isi dataset, jumlah baris/kolom, dan tipe data.
# *   Langkah 2: Siapkan Data
#
#     Bersihkan data dari nilai KOsonh/duplikat,Ubah data Kategorialkan jadi angka jika perlu
#
# *   Langkah 3: Analisis dan Modeling
#
#     Hitung rasio pasien/staf, Pasien/Tempat Tidur, buat grafik, dan coba model prediksi sederhana.
#
# *   Langkah 4: Evaluasi
#
#     Melihat hasil analisis, tentukan dapartemen yang paling sibuk, dan buat rekomendasi
